# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
x=[]
y=[]
c=0
zeros = 0
import numpy as np
import os
for file in os.listdir("/kaggle/input/contrails-images-ash-color/contrails"):
    if(c<2000): #Initially Considering Only 1000 Images. Will Be Scaling Up Later.
        a=np.load("/kaggle/input/contrails-images-ash-color/contrails/"+file)
        xa=a[:,:,:3]
        ya=a[:,:,3]
        if(np.sum(ya)>1000 and (c-zeros) <1500):
            x.append(xa.astype('float32'))
            y.append(ya.astype('float32'))
            c+=1
        elif(1 not in ya and zeros<500):
            x.append(xa.astype('float32'))
            y.append(ya.astype('float32'))
            zeros+=1
            c+=1
    else:
        break

# %%
x=np.array(x)
y=np.array(y)
print(x.shape)
print(y.shape)
# Out:
# (2000, 256, 256, 3)
# (2000, 256, 256)

# %%
y = y.reshape(2000,256,256,1)

# %%
# !pip install -U -q segmentation-models
# !pip install -q tensorflow
# !pip install -q keras
import os
os.environ["SM_FRAMEWORK"] = "tf.keras"
from tensorflow import keras
import segmentation_models as sm
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")
# Segmentation Models: using `tf.keras` framework.

# %%
import tensorflow as tf
import cv2 
import numpy as np
import matplotlib.pyplot as plt
BACKBONE = 'resnet50'

# %%
import segmentation_models
from segmentation_models import FPN
from keras import backend as K
def dice_loss(y_true, y_pred, smooth=1):
    intersection = K.sum(y_true * y_pred, axis=[1, 2, 3])
    total_pixels = K.sum(y_true, axis=[1, 2, 3]) + K.sum(y_pred, axis=[1, 2, 3])
    dice_coefficient = (2. * intersection + smooth) / (total_pixels + smooth)
    return 1. - dice_coefficient

# %%
model = FPN(BACKBONE,input_shape = (256,256,3),encoder_weights='imagenet',classes=1,encoder_freeze=True)
#Using 'resnet34'(Residual Network) architecture as backbone architecture 
#Using encoder_weights(feature detector values) from the popular 'Imagenet' dataset , a kind of pre trainded weights
model.compile(optimizer='adam',loss=dice_loss,metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  data (InputLayer)              [(None, 256, 256, 3  0           []
#                                 )]
#
#  bn_data (BatchNormalization)   (None, 256, 256, 3)  9           ['data[0][0]']
#
#  zero_padding2d_70 (ZeroPadding  (None, 262, 262, 3)  0          ['bn_data[0][0]']
#  2D)
#
#  conv0 (Conv2D)                 (None, 128, 128, 64  9408        ['zero_padding2d_70[0][0]']
#                                 )
#
#  bn0 (BatchNormalization)       (None, 128, 128, 64  256         ['conv0[0][0]']
#                                 )
#
#  relu0 (Activation)             (None, 128, 128, 64  0           ['bn0[0][0]']
#                                 )
#
#  zero_padding2d_71 (ZeroPadding  (None, 130, 130, 64  0          ['relu0[0][0]']
#  2D)                            )
#
#  pooling0 (MaxPooling2D)        (None, 64, 64, 64)   0           ['zero_padding2d_71[0][0]']
#
#  stage1_unit1_bn1 (BatchNormali  (None, 64, 64, 64)  256         ['pooling0[0][0]']
#  zation)
#
#  stage1_unit1_relu1 (Activation  (None, 64, 64, 64)  0           ['stage1_unit1_bn1[0][0]']
#  )
#
#  stage1_unit1_conv1 (Conv2D)    (None, 64, 64, 64)   4096        ['stage1_unit1_relu1[0][0]']
#
#  stage1_unit1_bn2 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit1_conv1[0][0]']
#  zation)
#
#  stage1_unit1_relu2 (Activation  (None, 64, 64, 64)  0           ['stage1_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_72 (ZeroPadding  (None, 66, 66, 64)  0           ['stage1_unit1_relu2[0][0]']
#  2D)
#
#  stage1_unit1_conv2 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_72[0][0]']
#
#  stage1_unit1_bn3 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit1_conv2[0][0]']
#  zation)
#
#  stage1_unit1_relu3 (Activation  (None, 64, 64, 64)  0           ['stage1_unit1_bn3[0][0]']
#  )
#
#  stage1_unit1_conv3 (Conv2D)    (None, 64, 64, 256)  16384       ['stage1_unit1_relu3[0][0]']
#
#  stage1_unit1_sc (Conv2D)       (None, 64, 64, 256)  16384       ['stage1_unit1_relu1[0][0]']
#
#  add_40 (Add)                   (None, 64, 64, 256)  0           ['stage1_unit1_conv3[0][0]',
#                                                                   'stage1_unit1_sc[0][0]']
#
#  stage1_unit2_bn1 (BatchNormali  (None, 64, 64, 256)  1024       ['add_40[0][0]']
#  zation)
#
#  stage1_unit2_relu1 (Activation  (None, 64, 64, 256)  0          ['stage1_unit2_bn1[0][0]']
#  )
#
#  stage1_unit2_conv1 (Conv2D)    (None, 64, 64, 64)   16384       ['stage1_unit2_relu1[0][0]']
#
#  stage1_unit2_bn2 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit2_conv1[0][0]']
#  zation)
#
#  stage1_unit2_relu2 (Activation  (None, 64, 64, 64)  0           ['stage1_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_73 (ZeroPadding  (None, 66, 66, 64)  0           ['stage1_unit2_relu2[0][0]']
#  2D)
#
#  stage1_unit2_conv2 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_73[0][0]']
#
#  stage1_unit2_bn3 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit2_conv2[0][0]']
#  zation)
#
#  stage1_unit2_relu3 (Activation  (None, 64, 64, 64)  0           ['stage1_unit2_bn3[0][0]']
#  )
#
#  stage1_unit2_conv3 (Conv2D)    (None, 64, 64, 256)  16384       ['stage1_unit2_relu3[0][0]']
#
#  add_41 (Add)                   (None, 64, 64, 256)  0           ['stage1_unit2_conv3[0][0]',
#                                                                   'add_40[0][0]']
#
#  stage1_unit3_bn1 (BatchNormali  (None, 64, 64, 256)  1024       ['add_41[0][0]']
#  zation)
#
#  stage1_unit3_relu1 (Activation  (None, 64, 64, 256)  0          ['stage1_unit3_bn1[0][0]']
#  )
#
#  stage1_unit3_conv1 (Conv2D)    (None, 64, 64, 64)   16384       ['stage1_unit3_relu1[0][0]']
#
#  stage1_unit3_bn2 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit3_conv1[0][0]']
#  zation)
#
#  stage1_unit3_relu2 (Activation  (None, 64, 64, 64)  0           ['stage1_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_74 (ZeroPadding  (None, 66, 66, 64)  0           ['stage1_unit3_relu2[0][0]']
#  2D)
#
#  stage1_unit3_conv2 (Conv2D)    (None, 64, 64, 64)   36864       ['zero_padding2d_74[0][0]']
#
#  stage1_unit3_bn3 (BatchNormali  (None, 64, 64, 64)  256         ['stage1_unit3_conv2[0][0]']
#  zation)
#
#  stage1_unit3_relu3 (Activation  (None, 64, 64, 64)  0           ['stage1_unit3_bn3[0][0]']
#  )
#
#  stage1_unit3_conv3 (Conv2D)    (None, 64, 64, 256)  16384       ['stage1_unit3_relu3[0][0]']
#
#  add_42 (Add)                   (None, 64, 64, 256)  0           ['stage1_unit3_conv3[0][0]',
#                                                                   'add_41[0][0]']
#
#  stage2_unit1_bn1 (BatchNormali  (None, 64, 64, 256)  1024       ['add_42[0][0]']
#  zation)
#
#  stage2_unit1_relu1 (Activation  (None, 64, 64, 256)  0          ['stage2_unit1_bn1[0][0]']
#  )
#
#  stage2_unit1_conv1 (Conv2D)    (None, 64, 64, 128)  32768       ['stage2_unit1_relu1[0][0]']
#
#  stage2_unit1_bn2 (BatchNormali  (None, 64, 64, 128)  512        ['stage2_unit1_conv1[0][0]']
#  zation)
#
#  stage2_unit1_relu2 (Activation  (None, 64, 64, 128)  0          ['stage2_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_75 (ZeroPadding  (None, 66, 66, 128)  0          ['stage2_unit1_relu2[0][0]']
#  2D)
#
#  stage2_unit1_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_75[0][0]']
#
#  stage2_unit1_bn3 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit1_conv2[0][0]']
#  zation)
#
#  stage2_unit1_relu3 (Activation  (None, 32, 32, 128)  0          ['stage2_unit1_bn3[0][0]']
#  )
#
#  stage2_unit1_conv3 (Conv2D)    (None, 32, 32, 512)  65536       ['stage2_unit1_relu3[0][0]']
#
#  stage2_unit1_sc (Conv2D)       (None, 32, 32, 512)  131072      ['stage2_unit1_relu1[0][0]']
#
#  add_43 (Add)                   (None, 32, 32, 512)  0           ['stage2_unit1_conv3[0][0]',
#                                                                   'stage2_unit1_sc[0][0]']
#
#  stage2_unit2_bn1 (BatchNormali  (None, 32, 32, 512)  2048       ['add_43[0][0]']
#  zation)
#
#  stage2_unit2_relu1 (Activation  (None, 32, 32, 512)  0          ['stage2_unit2_bn1[0][0]']
#  )
#
#  stage2_unit2_conv1 (Conv2D)    (None, 32, 32, 128)  65536       ['stage2_unit2_relu1[0][0]']
#
#  stage2_unit2_bn2 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit2_conv1[0][0]']
#  zation)
#
#  stage2_unit2_relu2 (Activation  (None, 32, 32, 128)  0          ['stage2_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_76 (ZeroPadding  (None, 34, 34, 128)  0          ['stage2_unit2_relu2[0][0]']
#  2D)
#
#  stage2_unit2_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_76[0][0]']
#
#  stage2_unit2_bn3 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit2_conv2[0][0]']
#  zation)
#
#  stage2_unit2_relu3 (Activation  (None, 32, 32, 128)  0          ['stage2_unit2_bn3[0][0]']
#  )
#
#  stage2_unit2_conv3 (Conv2D)    (None, 32, 32, 512)  65536       ['stage2_unit2_relu3[0][0]']
#
#  add_44 (Add)                   (None, 32, 32, 512)  0           ['stage2_unit2_conv3[0][0]',
#                                                                   'add_43[0][0]']
#
#  stage2_unit3_bn1 (BatchNormali  (None, 32, 32, 512)  2048       ['add_44[0][0]']
#  zation)
#
#  stage2_unit3_relu1 (Activation  (None, 32, 32, 512)  0          ['stage2_unit3_bn1[0][0]']
#  )
#
#  stage2_unit3_conv1 (Conv2D)    (None, 32, 32, 128)  65536       ['stage2_unit3_relu1[0][0]']
#
#  stage2_unit3_bn2 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit3_conv1[0][0]']
#  zation)
#
#  stage2_unit3_relu2 (Activation  (None, 32, 32, 128)  0          ['stage2_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_77 (ZeroPadding  (None, 34, 34, 128)  0          ['stage2_unit3_relu2[0][0]']
#  2D)
#
#  stage2_unit3_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_77[0][0]']
#
#  stage2_unit3_bn3 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit3_conv2[0][0]']
#  zation)
#
#  stage2_unit3_relu3 (Activation  (None, 32, 32, 128)  0          ['stage2_unit3_bn3[0][0]']
#  )
#
#  stage2_unit3_conv3 (Conv2D)    (None, 32, 32, 512)  65536       ['stage2_unit3_relu3[0][0]']
#
#  add_45 (Add)                   (None, 32, 32, 512)  0           ['stage2_unit3_conv3[0][0]',
#                                                                   'add_44[0][0]']
#
#  stage2_unit4_bn1 (BatchNormali  (None, 32, 32, 512)  2048       ['add_45[0][0]']
#  zation)
#
#  stage2_unit4_relu1 (Activation  (None, 32, 32, 512)  0          ['stage2_unit4_bn1[0][0]']
#  )
#
#  stage2_unit4_conv1 (Conv2D)    (None, 32, 32, 128)  65536       ['stage2_unit4_relu1[0][0]']
#
#  stage2_unit4_bn2 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit4_conv1[0][0]']
#  zation)
#
#  stage2_unit4_relu2 (Activation  (None, 32, 32, 128)  0          ['stage2_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_78 (ZeroPadding  (None, 34, 34, 128)  0          ['stage2_unit4_relu2[0][0]']
#  2D)
#
#  stage2_unit4_conv2 (Conv2D)    (None, 32, 32, 128)  147456      ['zero_padding2d_78[0][0]']
#
#  stage2_unit4_bn3 (BatchNormali  (None, 32, 32, 128)  512        ['stage2_unit4_conv2[0][0]']
#  zation)
#
#  stage2_unit4_relu3 (Activation  (None, 32, 32, 128)  0          ['stage2_unit4_bn3[0][0]']
#  )
#
#  stage2_unit4_conv3 (Conv2D)    (None, 32, 32, 512)  65536       ['stage2_unit4_relu3[0][0]']
#
#  add_46 (Add)                   (None, 32, 32, 512)  0           ['stage2_unit4_conv3[0][0]',
#                                                                   'add_45[0][0]']
#
#  stage3_unit1_bn1 (BatchNormali  (None, 32, 32, 512)  2048       ['add_46[0][0]']
#  zation)
#
#  stage3_unit1_relu1 (Activation  (None, 32, 32, 512)  0          ['stage3_unit1_bn1[0][0]']
#  )
#
#  stage3_unit1_conv1 (Conv2D)    (None, 32, 32, 256)  131072      ['stage3_unit1_relu1[0][0]']
#
#  stage3_unit1_bn2 (BatchNormali  (None, 32, 32, 256)  1024       ['stage3_unit1_conv1[0][0]']
#  zation)
#
#  stage3_unit1_relu2 (Activation  (None, 32, 32, 256)  0          ['stage3_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_79 (ZeroPadding  (None, 34, 34, 256)  0          ['stage3_unit1_relu2[0][0]']
#  2D)
#
#  stage3_unit1_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_79[0][0]']
#
#  stage3_unit1_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit1_conv2[0][0]']
#  zation)
#
#  stage3_unit1_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit1_bn3[0][0]']
#  )
#
#  stage3_unit1_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit1_relu3[0][0]']
#                                 )
#
#  stage3_unit1_sc (Conv2D)       (None, 16, 16, 1024  524288      ['stage3_unit1_relu1[0][0]']
#                                 )
#
#  add_47 (Add)                   (None, 16, 16, 1024  0           ['stage3_unit1_conv3[0][0]',
#                                 )                                 'stage3_unit1_sc[0][0]']
#
#  stage3_unit2_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_47[0][0]']
#  zation)                        )
#
#  stage3_unit2_relu1 (Activation  (None, 16, 16, 1024  0          ['stage3_unit2_bn1[0][0]']
#  )                              )
#
#  stage3_unit2_conv1 (Conv2D)    (None, 16, 16, 256)  262144      ['stage3_unit2_relu1[0][0]']
#
#  stage3_unit2_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit2_conv1[0][0]']
#  zation)
#
#  stage3_unit2_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_80 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit2_relu2[0][0]']
#  2D)
#
#  stage3_unit2_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_80[0][0]']
#
#  stage3_unit2_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit2_conv2[0][0]']
#  zation)
#
#  stage3_unit2_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit2_bn3[0][0]']
#  )
#
#  stage3_unit2_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit2_relu3[0][0]']
#                                 )
#
#  add_48 (Add)                   (None, 16, 16, 1024  0           ['stage3_unit2_conv3[0][0]',
#                                 )                                 'add_47[0][0]']
#
#  stage3_unit3_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_48[0][0]']
#  zation)                        )
#
#  stage3_unit3_relu1 (Activation  (None, 16, 16, 1024  0          ['stage3_unit3_bn1[0][0]']
#  )                              )
#
#  stage3_unit3_conv1 (Conv2D)    (None, 16, 16, 256)  262144      ['stage3_unit3_relu1[0][0]']
#
#  stage3_unit3_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit3_conv1[0][0]']
#  zation)
#
#  stage3_unit3_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_81 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit3_relu2[0][0]']
#  2D)
#
#  stage3_unit3_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_81[0][0]']
#
#  stage3_unit3_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit3_conv2[0][0]']
#  zation)
#
#  stage3_unit3_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit3_bn3[0][0]']
#  )
#
#  stage3_unit3_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit3_relu3[0][0]']
#                                 )
#
#  add_49 (Add)                   (None, 16, 16, 1024  0           ['stage3_unit3_conv3[0][0]',
#                                 )                                 'add_48[0][0]']
#
#  stage3_unit4_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_49[0][0]']
#  zation)                        )
#
#  stage3_unit4_relu1 (Activation  (None, 16, 16, 1024  0          ['stage3_unit4_bn1[0][0]']
#  )                              )
#
#  stage3_unit4_conv1 (Conv2D)    (None, 16, 16, 256)  262144      ['stage3_unit4_relu1[0][0]']
#
#  stage3_unit4_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit4_conv1[0][0]']
#  zation)
#
#  stage3_unit4_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit4_bn2[0][0]']
#  )
#
#  zero_padding2d_82 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit4_relu2[0][0]']
#  2D)
#
#  stage3_unit4_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_82[0][0]']
#
#  stage3_unit4_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit4_conv2[0][0]']
#  zation)
#
#  stage3_unit4_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit4_bn3[0][0]']
#  )
#
#  stage3_unit4_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit4_relu3[0][0]']
#                                 )
#
#  add_50 (Add)                   (None, 16, 16, 1024  0           ['stage3_unit4_conv3[0][0]',
#                                 )                                 'add_49[0][0]']
#
#  stage3_unit5_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_50[0][0]']
#  zation)                        )
#
#  stage3_unit5_relu1 (Activation  (None, 16, 16, 1024  0          ['stage3_unit5_bn1[0][0]']
#  )                              )
#
#  stage3_unit5_conv1 (Conv2D)    (None, 16, 16, 256)  262144      ['stage3_unit5_relu1[0][0]']
#
#  stage3_unit5_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit5_conv1[0][0]']
#  zation)
#
#  stage3_unit5_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit5_bn2[0][0]']
#  )
#
#  zero_padding2d_83 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit5_relu2[0][0]']
#  2D)
#
#  stage3_unit5_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_83[0][0]']
#
#  stage3_unit5_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit5_conv2[0][0]']
#  zation)
#
#  stage3_unit5_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit5_bn3[0][0]']
#  )
#
#  stage3_unit5_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit5_relu3[0][0]']
#                                 )
#
#  add_51 (Add)                   (None, 16, 16, 1024  0           ['stage3_unit5_conv3[0][0]',
#                                 )                                 'add_50[0][0]']
#
#  stage3_unit6_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_51[0][0]']
#  zation)                        )
#
#  stage3_unit6_relu1 (Activation  (None, 16, 16, 1024  0          ['stage3_unit6_bn1[0][0]']
#  )                              )
#
#  stage3_unit6_conv1 (Conv2D)    (None, 16, 16, 256)  262144      ['stage3_unit6_relu1[0][0]']
#
#  stage3_unit6_bn2 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit6_conv1[0][0]']
#  zation)
#
#  stage3_unit6_relu2 (Activation  (None, 16, 16, 256)  0          ['stage3_unit6_bn2[0][0]']
#  )
#
#  zero_padding2d_84 (ZeroPadding  (None, 18, 18, 256)  0          ['stage3_unit6_relu2[0][0]']
#  2D)
#
#  stage3_unit6_conv2 (Conv2D)    (None, 16, 16, 256)  589824      ['zero_padding2d_84[0][0]']
#
#  stage3_unit6_bn3 (BatchNormali  (None, 16, 16, 256)  1024       ['stage3_unit6_conv2[0][0]']
#  zation)
#
#  stage3_unit6_relu3 (Activation  (None, 16, 16, 256)  0          ['stage3_unit6_bn3[0][0]']
#  )
#
#  stage3_unit6_conv3 (Conv2D)    (None, 16, 16, 1024  262144      ['stage3_unit6_relu3[0][0]']
#                                 )
#
#  add_52 (Add)                   (None, 16, 16, 1024  0           ['stage3_unit6_conv3[0][0]',
#                                 )                                 'add_51[0][0]']
#
#  stage4_unit1_bn1 (BatchNormali  (None, 16, 16, 1024  4096       ['add_52[0][0]']
#  zation)                        )
#
#  stage4_unit1_relu1 (Activation  (None, 16, 16, 1024  0          ['stage4_unit1_bn1[0][0]']
#  )                              )
#
#  stage4_unit1_conv1 (Conv2D)    (None, 16, 16, 512)  524288      ['stage4_unit1_relu1[0][0]']
#
#  stage4_unit1_bn2 (BatchNormali  (None, 16, 16, 512)  2048       ['stage4_unit1_conv1[0][0]']
#  zation)
#
#  stage4_unit1_relu2 (Activation  (None, 16, 16, 512)  0          ['stage4_unit1_bn2[0][0]']
#  )
#
#  zero_padding2d_85 (ZeroPadding  (None, 18, 18, 512)  0          ['stage4_unit1_relu2[0][0]']
#  2D)
#
#  stage4_unit1_conv2 (Conv2D)    (None, 8, 8, 512)    2359296     ['zero_padding2d_85[0][0]']
#
#  stage4_unit1_bn3 (BatchNormali  (None, 8, 8, 512)   2048        ['stage4_unit1_conv2[0][0]']
#  zation)
#
#  stage4_unit1_relu3 (Activation  (None, 8, 8, 512)   0           ['stage4_unit1_bn3[0][0]']
#  )
#
#  stage4_unit1_conv3 (Conv2D)    (None, 8, 8, 2048)   1048576     ['stage4_unit1_relu3[0][0]']
#
#  stage4_unit1_sc (Conv2D)       (None, 8, 8, 2048)   2097152     ['stage4_unit1_relu1[0][0]']
#
#  add_53 (Add)                   (None, 8, 8, 2048)   0           ['stage4_unit1_conv3[0][0]',
#                                                                   'stage4_unit1_sc[0][0]']
#
#  stage4_unit2_bn1 (BatchNormali  (None, 8, 8, 2048)  8192        ['add_53[0][0]']
#  zation)
#
#  stage4_unit2_relu1 (Activation  (None, 8, 8, 2048)  0           ['stage4_unit2_bn1[0][0]']
#  )
#
#  stage4_unit2_conv1 (Conv2D)    (None, 8, 8, 512)    1048576     ['stage4_unit2_relu1[0][0]']
#
#  stage4_unit2_bn2 (BatchNormali  (None, 8, 8, 512)   2048        ['stage4_unit2_conv1[0][0]']
#  zation)
#
#  stage4_unit2_relu2 (Activation  (None, 8, 8, 512)   0           ['stage4_unit2_bn2[0][0]']
#  )
#
#  zero_padding2d_86 (ZeroPadding  (None, 10, 10, 512)  0          ['stage4_unit2_relu2[0][0]']
#  2D)
#
#  stage4_unit2_conv2 (Conv2D)    (None, 8, 8, 512)    2359296     ['zero_padding2d_86[0][0]']
#
#  stage4_unit2_bn3 (BatchNormali  (None, 8, 8, 512)   2048        ['stage4_unit2_conv2[0][0]']
#  zation)
#
#  stage4_unit2_relu3 (Activation  (None, 8, 8, 512)   0           ['stage4_unit2_bn3[0][0]']
#  )
# ...
#  zation)
#
#  stage4_unit3_relu1 (Activation  (None, 8, 8, 2048)  0           ['stage4_unit3_bn1[0][0]']
#  )
#
#  stage4_unit3_conv1 (Conv2D)    (None, 8, 8, 512)    1048576     ['stage4_unit3_relu1[0][0]']
#
#  stage4_unit3_bn2 (BatchNormali  (None, 8, 8, 512)   2048        ['stage4_unit3_conv1[0][0]']
#  zation)
#
#  stage4_unit3_relu2 (Activation  (None, 8, 8, 512)   0           ['stage4_unit3_bn2[0][0]']
#  )
#
#  zero_padding2d_87 (ZeroPadding  (None, 10, 10, 512)  0          ['stage4_unit3_relu2[0][0]']
#  2D)
#
#  stage4_unit3_conv2 (Conv2D)    (None, 8, 8, 512)    2359296     ['zero_padding2d_87[0][0]']
#
#  stage4_unit3_bn3 (BatchNormali  (None, 8, 8, 512)   2048        ['stage4_unit3_conv2[0][0]']
#  zation)
#
#  stage4_unit3_relu3 (Activation  (None, 8, 8, 512)   0           ['stage4_unit3_bn3[0][0]']
#  )
#
#  stage4_unit3_conv3 (Conv2D)    (None, 8, 8, 2048)   1048576     ['stage4_unit3_relu3[0][0]']
#
#  add_55 (Add)                   (None, 8, 8, 2048)   0           ['stage4_unit3_conv3[0][0]',
#                                                                   'add_54[0][0]']
#
#  bn1 (BatchNormalization)       (None, 8, 8, 2048)   8192        ['add_55[0][0]']
#
#  relu1 (Activation)             (None, 8, 8, 2048)   0           ['bn1[0][0]']
#
#  fpn_stage_p5_pre_conv (Conv2D)  (None, 8, 8, 256)   524544      ['relu1[0][0]']
#
#  fpn_stage_p5_upsampling (UpSam  (None, 16, 16, 256)  0          ['fpn_stage_p5_pre_conv[0][0]']
#  pling2D)
#
#  fpn_stage_p5_conv (Conv2D)     (None, 16, 16, 256)  262400      ['stage4_unit1_relu1[0][0]']
#
#  fpn_stage_p5_add (Add)         (None, 16, 16, 256)  0           ['fpn_stage_p5_upsampling[0][0]',
#                                                                   'fpn_stage_p5_conv[0][0]']
#
#  fpn_stage_p4_upsampling (UpSam  (None, 32, 32, 256)  0          ['fpn_stage_p5_add[0][0]']
#  pling2D)
#
#  fpn_stage_p4_conv (Conv2D)     (None, 32, 32, 256)  131328      ['stage3_unit1_relu1[0][0]']
#
#  fpn_stage_p4_add (Add)         (None, 32, 32, 256)  0           ['fpn_stage_p4_upsampling[0][0]',
#                                                                   'fpn_stage_p4_conv[0][0]']
#
#  fpn_stage_p3_upsampling (UpSam  (None, 64, 64, 256)  0          ['fpn_stage_p4_add[0][0]']
#  pling2D)
#
#  fpn_stage_p3_conv (Conv2D)     (None, 64, 64, 256)  65792       ['stage2_unit1_relu1[0][0]']
#
#  fpn_stage_p3_add (Add)         (None, 64, 64, 256)  0           ['fpn_stage_p3_upsampling[0][0]',
#                                                                   'fpn_stage_p3_conv[0][0]']
#
#  fpn_stage_p2_upsampling (UpSam  (None, 128, 128, 25  0          ['fpn_stage_p3_add[0][0]']
#  pling2D)                       6)
#
#  fpn_stage_p2_conv (Conv2D)     (None, 128, 128, 25  16640       ['relu0[0][0]']
#                                 6)
#
#  fpn_stage_p2_add (Add)         (None, 128, 128, 25  0           ['fpn_stage_p2_upsampling[0][0]',
#                                 6)                                'fpn_stage_p2_conv[0][0]']
#
#  segm_stage3a_conv (Conv2D)     (None, 64, 64, 128)  294912      ['fpn_stage_p3_add[0][0]']
#
#  segm_stage4a_conv (Conv2D)     (None, 32, 32, 128)  294912      ['fpn_stage_p4_add[0][0]']
#
#  segm_stage5a_conv (Conv2D)     (None, 16, 16, 128)  294912      ['fpn_stage_p5_add[0][0]']
#
#  segm_stage2a_conv (Conv2D)     (None, 128, 128, 12  294912      ['fpn_stage_p2_add[0][0]']
#                                 8)
#
#  segm_stage3a_bn (BatchNormaliz  (None, 64, 64, 128)  512        ['segm_stage3a_conv[0][0]']
#  ation)
#
#  segm_stage4a_bn (BatchNormaliz  (None, 32, 32, 128)  512        ['segm_stage4a_conv[0][0]']
#  ation)
#
#  segm_stage5a_bn (BatchNormaliz  (None, 16, 16, 128)  512        ['segm_stage5a_conv[0][0]']
#  ation)
#
#  segm_stage2a_bn (BatchNormaliz  (None, 128, 128, 12  512        ['segm_stage2a_conv[0][0]']
#  ation)                         8)
#
#  segm_stage3a_relu (Activation)  (None, 64, 64, 128)  0          ['segm_stage3a_bn[0][0]']
#
#  segm_stage4a_relu (Activation)  (None, 32, 32, 128)  0          ['segm_stage4a_bn[0][0]']
#
#  segm_stage5a_relu (Activation)  (None, 16, 16, 128)  0          ['segm_stage5a_bn[0][0]']
#
#  segm_stage2a_relu (Activation)  (None, 128, 128, 12  0          ['segm_stage2a_bn[0][0]']
#                                 8)
#
#  segm_stage3b_conv (Conv2D)     (None, 64, 64, 128)  147456      ['segm_stage3a_relu[0][0]']
#
#  segm_stage4b_conv (Conv2D)     (None, 32, 32, 128)  147456      ['segm_stage4a_relu[0][0]']
#
#  segm_stage5b_conv (Conv2D)     (None, 16, 16, 128)  147456      ['segm_stage5a_relu[0][0]']
#
#  segm_stage2b_conv (Conv2D)     (None, 128, 128, 12  147456      ['segm_stage2a_relu[0][0]']
#                                 8)
#
#  segm_stage3b_bn (BatchNormaliz  (None, 64, 64, 128)  512        ['segm_stage3b_conv[0][0]']
#  ation)
#
#  segm_stage4b_bn (BatchNormaliz  (None, 32, 32, 128)  512        ['segm_stage4b_conv[0][0]']
#  ation)
#
#  segm_stage5b_bn (BatchNormaliz  (None, 16, 16, 128)  512        ['segm_stage5b_conv[0][0]']
#  ation)
#
#  segm_stage2b_bn (BatchNormaliz  (None, 128, 128, 12  512        ['segm_stage2b_conv[0][0]']
#  ation)                         8)
#
#  segm_stage3b_relu (Activation)  (None, 64, 64, 128)  0          ['segm_stage3b_bn[0][0]']
#
#  segm_stage4b_relu (Activation)  (None, 32, 32, 128)  0          ['segm_stage4b_bn[0][0]']
#
#  segm_stage5b_relu (Activation)  (None, 16, 16, 128)  0          ['segm_stage5b_bn[0][0]']
#
#  segm_stage2b_relu (Activation)  (None, 128, 128, 12  0          ['segm_stage2b_bn[0][0]']
#                                 8)
#
#  upsampling_stage3 (UpSampling2  (None, 128, 128, 12  0          ['segm_stage3b_relu[0][0]']
#  D)                             8)
#
#  upsampling_stage4 (UpSampling2  (None, 128, 128, 12  0          ['segm_stage4b_relu[0][0]']
#  D)                             8)
#
#  upsampling_stage5 (UpSampling2  (None, 128, 128, 12  0          ['segm_stage5b_relu[0][0]']
#  D)                             8)
#
#  aggregation_concat (Concatenat  (None, 128, 128, 51  0          ['segm_stage2b_relu[0][0]',
#  e)                             2)                                'upsampling_stage3[0][0]',
#                                                                   'upsampling_stage4[0][0]',
#                                                                   'upsampling_stage5[0][0]']
#
#  final_stage_conv (Conv2D)      (None, 128, 128, 12  589824      ['aggregation_concat[0][0]']
#                                 8)
#
#  final_stage_bn (BatchNormaliza  (None, 128, 128, 12  512        ['final_stage_conv[0][0]']
#  tion)                          8)
#
#  final_stage_relu (Activation)  (None, 128, 128, 12  0           ['final_stage_bn[0][0]']
#                                 8)
#
#  final_upsampling (UpSampling2D  (None, 256, 256, 12  0          ['final_stage_relu[0][0]']
#  )                              8)
#
#  head_conv (Conv2D)             (None, 256, 256, 1)  1153        ['final_upsampling[0][0]']
#
#  softmax (Activation)           (None, 256, 256, 1)  0           ['head_conv[0][0]']
#
# ==================================================================================================
# Total params: 26,911,818
# Trainable params: 3,409,028
# Non-trainable params: 23,502,790
# __________________________________________________________________________________________________
# None

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=10)
print('Training Set Size ',len(xtrain))
print('Testing Set Size ',len(xtest))
# Out:
# Training Set Size  1600
# Testing Set Size  400

# %%
results = model.fit(xtrain,ytrain,validation_split=0.2,batch_size=25,epochs= 32)
# Out:
# Epoch 1/32
# 52/52 [==============================] - 59s 594ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 2/32
# 52/52 [==============================] - 26s 498ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 3/32
# 52/52 [==============================] - 26s 499ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 4/32
# 52/52 [==============================] - 26s 499ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 5/32
# 52/52 [==============================] - 26s 499ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 6/32
# 52/52 [==============================] - 26s 504ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 7/32
# 52/52 [==============================] - 26s 504ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 8/32
# 52/52 [==============================] - 26s 504ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 9/32
# 52/52 [==============================] - 26s 505ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 10/32
# 52/52 [==============================] - 26s 504ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 11/32
# 52/52 [==============================] - 26s 498ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 12/32
# 52/52 [==============================] - 26s 499ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 13/32
# 52/52 [==============================] - 26s 505ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 14/32
# 52/52 [==============================] - 26s 505ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 15/32
# 52/52 [==============================] - 26s 505ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 16/32
# 52/52 [==============================] - 26s 505ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 17/32
# 52/52 [==============================] - 26s 504ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 18/32
# 52/52 [==============================] - 26s 505ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 19/32
# 52/52 [==============================] - 26s 505ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 20/32
# 52/52 [==============================] - 26s 499ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 21/32
# 52/52 [==============================] - 26s 499ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 22/32
# 52/52 [==============================] - 26s 499ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 23/32
# 52/52 [==============================] - 26s 505ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 24/32
# 52/52 [==============================] - 26s 504ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 25/32
# 52/52 [==============================] - 26s 504ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 26/32
# 52/52 [==============================] - 26s 504ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 27/32
# 52/52 [==============================] - 26s 499ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 28/32
# 52/52 [==============================] - 26s 505ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 29/32
# 52/52 [==============================] - 26s 505ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 30/32
# 52/52 [==============================] - 26s 499ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 31/32
# 52/52 [==============================] - 26s 499ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241
# Epoch 32/32
# 52/52 [==============================] - 26s 504ms/step - loss: 0.9538 - accuracy: 0.0241 - val_loss: 0.9537 - val_accuracy: 0.0241

# %%
y_pred = model.predict(xtest)
y_pred_thresholded = y_pred > 0.5
print(ytest.dtype)
print(y_pred_thresholded.dtype)
intersection = np.logical_and(ytest,y_pred_thresholded)
union = np.logical_or(ytest,y_pred_thresholded)
iou_score = np.sum(intersection)/np.sum(union)
print("IoU score is:",iou_score)
# Out:
# 13/13 [==============================] - 11s 459ms/step
# float32
# bool
# IoU score is: 0.02378868103027344

# %%
import matplotlib.pyplot as plt
xt=xtest[13]
yt=ytest[13]

# %%
test_img = xtest[20]
test_img = cv2.cvtColor(test_img,cv2.COLOR_RGB2BGR)
test_img = np.expand_dims(test_img,axis=0)
print(test_img.shape)
prediction=model.predict(test_img)
print(prediction.shape)
prediction = prediction.reshape(256,256,1)
print(ytest[19].shape)
# Out:
# (1, 256, 256, 3)
# 1/1 [==============================] - 1s 1s/step
# (1, 256, 256, 1)
# (256, 256, 1)

# %%
plt.imshow(prediction)
print(np.sum(prediction))
#predicted image
# Out:
# 65536.0

# %%
plt.imshow(ytest[20])
print(np.sum(ytest))
#Actual image
# Out:
# 623606.0

# %%
from tensorflow.keras.utils import plot_model
plot_model(model, to_file='fpn_model.png', show_shapes=True, show_layer_names=True)
